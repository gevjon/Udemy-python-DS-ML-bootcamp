# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.7 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
fig = plt.figure(figsize=(7.5,2))
axes = fig.add_axes([-0.2,-0.2,1.2,1.2])
axes.scatter(x='a',y='b',data=df3,color='r',edgecolor='k')
axes.set_xlabel('a')
axes.set_ylabel('b')

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %%
df3['a'].plot.hist(edgecolor='k')

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')
df3['a'].plot.hist(edgecolor='w',alpha=0.5,bins=20)

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.**

# %%
df3.plot(x=['a','b'],kind='box') # using pandas built-in

# %%
df3.plot.box(x=['a','b'])

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.boxplot(x=[df3['a'],df3['b']]) #using object orientd plot of matplotlib
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x10a36b7f0>,
#   <matplotlib.lines.Line2D at 0x10a3817f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x10a365908>,
#   <matplotlib.lines.Line2D at 0x10a38bfd0>,
#   <matplotlib.lines.Line2D at 0x10a37c6d8>,
#   <matplotlib.lines.Line2D at 0x10a2db8d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10a387940>,
#   <matplotlib.lines.Line2D at 0x10a379e10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x10a38b588>,
#   <matplotlib.lines.Line2D at 0x10a2dbe10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x109e698d0>,
#   <matplotlib.lines.Line2D at 0x10a3650f0>,
#   <matplotlib.lines.Line2D at 0x10a381f60>,
#   <matplotlib.lines.Line2D at 0x10a37c390>]}

# %%
plt.boxplot([df3['a'],df3['b']]) #using matplotlib to plot directly
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x10a463dd8>,
#   <matplotlib.lines.Line2D at 0x10a367860>],
#  'caps': [<matplotlib.lines.Line2D at 0x10a36f898>,
#   <matplotlib.lines.Line2D at 0x10a36ffd0>,
#   <matplotlib.lines.Line2D at 0x10a354b38>,
#   <matplotlib.lines.Line2D at 0x10a351a20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10a363a90>,
#   <matplotlib.lines.Line2D at 0x10a35ca90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x10a363278>,
#   <matplotlib.lines.Line2D at 0x10a351ba8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x109bc93c8>,
#   <matplotlib.lines.Line2D at 0x10a347f98>,
#   <matplotlib.lines.Line2D at 0x10a367ac8>,
#   <matplotlib.lines.Line2D at 0x10a3549b0>]}

# %%
#import seaborn as sns #seaborn 画不起来

# %%
#solution
df3[['a','b']].plot.box()

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
df3['d'].plot.kde()

# %% [markdown]
# ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
df3['d'].plot.kde(linewidth=4,linestyle='--')

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
df3.plot.area(alpha=0.5,cmap='coolwarm')

# %%
#solution
df3.ix[0:30].plot.area(alpha=0.4)

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# ** Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
df3.ix[0:30].plot.area(alpha=0.4)
# Out:
#   File "<ipython-input-65-d9337211e23c>", line 1
#     df3.ix[0:30].plot.area(alpha=0.4,ax.legend(loc=center))
#                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
#solution
f = plt.figure()
df3.ix[0:30].plot.area(alpha=0.4,ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Great Job!
